# %% [markdown]
# ## Part 1: Indexing and Geometry Refinement
#
# The first step in data processing is to determine the diffraction geometry and crystal orientation by analyzing the locations of strong Bragg peaks. These steps are performed using [DIALS](https://dials.github.io), a suite of programs for integrating and scaling Bragg data. For our purposes, we will only use indexing and geometry refinement tools. Normally these steps would be followed by integration and scaling, but we will skip them to save time. For a more complete *DIALS* tutorial, see [Processing in Detail](https://dials.github.io/documentation/tutorials/processing_in_detail_betalactamase.html).
#
# Typically *DIALS* programs are run from the command line. Here we run *DIALS* from within the notebook using an exclamation point to execute each command in a shell. To run the command, click in the cell and press shift-Enter.

# %% [markdown]
# ### Metadata import
#
# The image file headers contain metadata specifying the experimental geometry such as X-ray wavelength, detector distance, oscillation increment per image. The command `dials.import` reads the image headers and outputs a json-formatted text file `imported.expt` containing the relevant metadata. Run the following command to import the insulin dataset:

# %%
# !dials.import images/insulin_2_1
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.24
# The following parameters have been modified:
#
# input {
#   experiments = <image files>
# }
#
# --------------------------------------------------------------------------------
#   format: <class 'dxtbx.format.FormatCBFMiniPilatusCHESS_6MSN127.FormatCBFMiniPilatusCHESS_6MSN127'>
#   template: /local/storage/steve/mdx2_dev/examples/insulin-tutorial/images/insulin_2_1/insulin_2_1_####.cbf.bz2:1:500
#   num images: 500
#   sequences:
#     still:    0
#     sweep:    1
#   num stills: 0
# --------------------------------------------------------------------------------
# Writing experiments to imported.expt

# %% [markdown]
# The imported geometry can be examined jupyter lab by double-clicking *imported.expt* in the file browser.
#
# `dials.show` can also be used to print the parameters as follows

# %%
# !dials.show imported.expt
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# The following parameters have been modified:
#
# input {
#   experiments = imported.expt
# }
#
# Experiment 0:
# Experiment identifier: 5ae0fd24-9eb4-995a-bbdb-0acb67b5b692
# Image template: /local/storage/steve/mdx2_dev/examples/insulin-tutorial/images/insulin_2_1/insulin_2_1_####.cbf.bz2
# Detector:
# Panel:
#   name: Panel
#   type: SENSOR_PAD
#   identifier:
#   pixel_size:{0.172,0.172}
#   image_size: {2463,2527}
#   trusted_range: {0,1.0098e+06}
#   thickness: 1
#   material: Si
#   mu: 3.92851
#   gain: 1
#   pedestal: 0
#   fast_axis: {1,0,0}
#   slow_axis: {0,-1,0}
#   origin: {-217.491,213.713,-260.05}
#   distance: 260.05
#   pixel to millimeter strategy: ParallaxCorrectedPxMmStrategy
#     mu: 3.92851
#     t0: 1
#
#
# Max resolution (at corners): 1.155825
# Max resolution (inscribed):  1.485702
#
# Beam:
#     probe: x-ray
#     wavelength: 0.9768
#     sample to source direction : {0,0,1}
#     divergence: 0
#     sigma divergence: 0
#     polarization normal: {0,1,0}
#     polarization fraction: 0.999
#     flux: 0
#     transmission: 1
#     sample to source distance: 0
#
# Beam centre:
#     mm: (217.49,213.71)
#     px: (1264.48,1242.52)
#
# Scan:
#     number of images:   500
#     image range:   {1,500}
#     epoch:    1.49845e+09
#     exposure time:    0.1
#     oscillation:   {160,0.1}
#
# Goniometer:
#     Rotation axis:   {-1,0,0}
#     Fixed rotation:  {1,0,0,0,1,0,0,0,1}
#     Setting rotation:{1,0,0,0,1,0,0,0,1}

# %% [markdown]
# ### Beamstop mask
#
# The beamstop mask must also be generated and added to the `imported.expt`. A beamstop mask is not essential for Bragg data processing, but it is important to create one for later import into *mdx2*. The mask can be drawn using the graphical image viewer that comes with *DIALS*:
#
# ```bash
# dials.image_viewer imported.expt
# ```
#
# Alternatively, the following will generate an appropriate circular mask for the insulin dataset using `dials.generate_mask` and `dials.apply_mask`.

# %%
# !dials.generate_mask imported.expt untrusted.circle=1264,1242,50
# !dials.apply_mask imported.expt input.mask=pixels.mask output.experiments=imported.expt
# Out:
# The following parameters have been modified:
#
# untrusted {
#   circle = 1264 1242 50
# }
# input {
#   experiments = imported.expt
# }
#
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# Writing mask to pixels.mask
# The following parameters have been modified:
#
# input {
#   mask = "pixels.mask"
#   experiments = imported.expt
# }
# output {
#   experiments = "imported.expt"
# }
#
# Writing experiments to imported.expt

# %% [markdown]
# ### Spotfinding
#
# Next, `dials.find_spots` will read all of the images and locate Bragg peaks. This requires reading in all of the diffraction images, and it can take a while depending on computational resources.

# %%
# !dials.find_spots imported.expt
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.24
# The following parameters have been modified:
#
# input {
#   experiments = imported.expt
# }
#
# Setting spotfinder.filter.min_spot_size=3
# Configuring spot finder from input parameters
# --------------------------------------------------------------------------------
# Finding strong spots in imageset 0
# --------------------------------------------------------------------------------
#
# Finding spots in image 1 to 500...
# Setting nproc=96
# Setting chunksize=6
# Extracting strong pixels from images
#  Using multiprocessing with 96 parallel job(s)
#
# Found 1651 strong pixels on image 1
# Found 1621 strong pixels on image 2
# Found 1342 strong pixels on image 3
# Found 1512 strong pixels on image 4
# Found 1602 strong pixels on image 5
# Found 1703 strong pixels on image 6
# Found 1812 strong pixels on image 7
# Found 1748 strong pixels on image 8
# Found 2024 strong pixels on image 9
# Found 2028 strong pixels on image 10
# Found 1791 strong pixels on image 11
# Found 1844 strong pixels on image 12
# Found 1502 strong pixels on image 13
# Found 1643 strong pixels on image 14
# Found 1609 strong pixels on image 15
# Found 1748 strong pixels on image 16
# Found 1794 strong pixels on image 17
# Found 1852 strong pixels on image 18
# Found 1886 strong pixels on image 19
# Found 1778 strong pixels on image 20
# Found 1595 strong pixels on image 21
# Found 1540 strong pixels on image 22
# Found 1638 strong pixels on image 23
# Found 1769 strong pixels on image 24
# Found 1856 strong pixels on image 25
# Found 1793 strong pixels on image 26
# Found 1692 strong pixels on image 27
# Found 1725 strong pixels on image 28
# Found 1661 strong pixels on image 29
# Found 1373 strong pixels on image 30
# Found 1634 strong pixels on image 31
# Found 1731 strong pixels on image 32
# Found 1506 strong pixels on image 33
# Found 1536 strong pixels on image 34
# Found 1763 strong pixels on image 35
# Found 1729 strong pixels on image 36
# Found 1823 strong pixels on image 37
# Found 1756 strong pixels on image 38
# Found 1569 strong pixels on image 39
# Found 1530 strong pixels on image 40
# Found 1773 strong pixels on image 41
# Found 1680 strong pixels on image 42
# Found 1671 strong pixels on image 43
# Found 1504 strong pixels on image 44
# Found 1786 strong pixels on image 45
# Found 1669 strong pixels on image 46
# Found 1720 strong pixels on image 47
# Found 1756 strong pixels on image 48
# Found 1771 strong pixels on image 49
# Found 1637 strong pixels on image 50
# Found 1821 strong pixels on image 51
# Found 1715 strong pixels on image 52
# Found 1746 strong pixels on image 53
# Found 1724 strong pixels on image 54
# Found 1589 strong pixels on image 55
# Found 1773 strong pixels on image 56
# Found 1710 strong pixels on image 57
# Found 1635 strong pixels on image 58
# Found 2128 strong pixels on image 59
# Found 1885 strong pixels on image 60
# Found 1749 strong pixels on image 61
# Found 1680 strong pixels on image 62
# Found 1800 strong pixels on image 63
# Found 1645 strong pixels on image 64
# Found 1923 strong pixels on image 65
# Found 1546 strong pixels on image 66
# Found 1517 strong pixels on image 67
# Found 1536 strong pixels on image 68
# Found 1735 strong pixels on image 69
# Found 1609 strong pixels on image 70
# Found 1821 strong pixels on image 71
# Found 1919 strong pixels on image 72
# Found 1740 strong pixels on image 73
# Found 1813 strong pixels on image 74
# Found 1652 strong pixels on image 75
# Found 1291 strong pixels on image 76
# Found 1500 strong pixels on image 77
# Found 1444 strong pixels on image 78
# Found 1643 strong pixels on image 79
# Found 1676 strong pixels on image 80
# Found 1607 strong pixels on image 81
# Found 1524 strong pixels on image 82
# Found 1567 strong pixels on image 83
# Found 1550 strong pixels on image 84
# Found 1548 strong pixels on image 85
# Found 1579 strong pixels on image 86
# Found 1270 strong pixels on image 87
# Found 1540 strong pixels on image 88
# Found 1499 strong pixels on image 89
# Found 1467 strong pixels on image 90
# Found 1504 strong pixels on image 91
# Found 1525 strong pixels on image 92
# Found 1404 strong pixels on image 93
# Found 1421 strong pixels on image 94
# Found 1464 strong pixels on image 95
# Found 1601 strong pixels on image 96
# Found 1508 strong pixels on image 97
# Found 1408 strong pixels on image 98
# Found 1421 strong pixels on image 99
# Found 1411 strong pixels on image 100
# Found 1549 strong pixels on image 101
# Found 1580 strong pixels on image 102
# Found 1707 strong pixels on image 103
# Found 1675 strong pixels on image 104
# Found 1700 strong pixels on image 105
# Found 1586 strong pixels on image 106
# Found 1610 strong pixels on image 107
# Found 1502 strong pixels on image 108
# Found 1501 strong pixels on image 109
# Found 1667 strong pixels on image 110
# Found 1338 strong pixels on image 111
# Found 1435 strong pixels on image 112
# Found 1562 strong pixels on image 113
# Found 1699 strong pixels on image 114
# Found 1616 strong pixels on image 115
# Found 1505 strong pixels on image 116
# Found 1490 strong pixels on image 117
# Found 1378 strong pixels on image 118
# Found 1439 strong pixels on image 119
# Found 1481 strong pixels on image 120
# Found 1333 strong pixels on image 121
# Found 1368 strong pixels on image 122
# Found 1474 strong pixels on image 123
# Found 1719 strong pixels on image 124
# Found 1470 strong pixels on image 125
# Found 1360 strong pixels on image 126
# Found 1282 strong pixels on image 127
# Found 1330 strong pixels on image 128
# Found 1615 strong pixels on image 129
# Found 1370 strong pixels on image 130
# Found 1553 strong pixels on image 131
# Found 1486 strong pixels on image 132
# Found 1618 strong pixels on image 133
# Found 1622 strong pixels on image 134
# Found 1335 strong pixels on image 135
# Found 1323 strong pixels on image 136
# Found 1449 strong pixels on image 137
# Found 1467 strong pixels on image 138
# Found 1395 strong pixels on image 139
# Found 1497 strong pixels on image 140
# Found 1573 strong pixels on image 141
# Found 1475 strong pixels on image 142
# Found 1298 strong pixels on image 143
# Found 1367 strong pixels on image 144
# Found 1170 strong pixels on image 145
# Found 1224 strong pixels on image 146
# Found 1305 strong pixels on image 147
# Found 1288 strong pixels on image 148
# Found 1363 strong pixels on image 149
# Found 1646 strong pixels on image 150
# Found 1435 strong pixels on image 151
# Found 1337 strong pixels on image 152
# Found 1330 strong pixels on image 153
# Found 1405 strong pixels on image 154
# Found 1388 strong pixels on image 155
# Found 1442 strong pixels on image 156
# Found 1497 strong pixels on image 157
# Found 1553 strong pixels on image 158
# Found 1510 strong pixels on image 159
# Found 1611 strong pixels on image 160
# Found 1304 strong pixels on image 161
# Found 1326 strong pixels on image 162
# Found 1269 strong pixels on image 163
# Found 1415 strong pixels on image 164
# Found 1370 strong pixels on image 165
# Found 1302 strong pixels on image 166
# Found 1335 strong pixels on image 167
# Found 1337 strong pixels on image 168
# Found 1283 strong pixels on image 169
# Found 1419 strong pixels on image 170
# Found 1377 strong pixels on image 171
# Found 1273 strong pixels on image 172
# Found 1387 strong pixels on image 173
# Found 1472 strong pixels on image 174
# Found 1708 strong pixels on image 175
# Found 1421 strong pixels on image 176
# Found 1306 strong pixels on image 177
# Found 1118 strong pixels on image 178
# Found 1321 strong pixels on image 179
# Found 1411 strong pixels on image 180
# Found 1345 strong pixels on image 181
# Found 1372 strong pixels on image 182
# Found 1253 strong pixels on image 183
# Found 1433 strong pixels on image 184
# Found 1200 strong pixels on image 185
# Found 1223 strong pixels on image 186
# Found 1512 strong pixels on image 187
# Found 1561 strong pixels on image 188
# Found 1324 strong pixels on image 189
# Found 1246 strong pixels on image 190
# Found 1273 strong pixels on image 191
# Found 1247 strong pixels on image 192
# Found 1260 strong pixels on image 193
# Found 1326 strong pixels on image 194
# Found 1384 strong pixels on image 195
# Found 1242 strong pixels on image 196
# Found 1302 strong pixels on image 197
# Found 1358 strong pixels on image 198
# Found 1294 strong pixels on image 199
# Found 1251 strong pixels on image 200
# Found 1186 strong pixels on image 201
# Found 1326 strong pixels on image 202
# Found 1256 strong pixels on image 203
# Found 1290 strong pixels on image 204
# Found 1146 strong pixels on image 205
# Found 1247 strong pixels on image 206
# Found 1444 strong pixels on image 207
# Found 1312 strong pixels on image 208
# Found 1357 strong pixels on image 209
# Found 1339 strong pixels on image 210
# Found 1385 strong pixels on image 211
# Found 1546 strong pixels on image 212
# Found 1389 strong pixels on image 213
# Found 1351 strong pixels on image 214
# Found 1595 strong pixels on image 215
# Found 1473 strong pixels on image 216
# Found 1488 strong pixels on image 217
# Found 1438 strong pixels on image 218
# Found 1290 strong pixels on image 219
# Found 1308 strong pixels on image 220
# Found 1376 strong pixels on image 221
# Found 1349 strong pixels on image 222
# Found 1332 strong pixels on image 223
# Found 1341 strong pixels on image 224
# Found 1142 strong pixels on image 225
# Found 1156 strong pixels on image 226
# Found 1216 strong pixels on image 227
# Found 1215 strong pixels on image 228
# Found 1245 strong pixels on image 229
# Found 1092 strong pixels on image 230
# Found 1169 strong pixels on image 231
# Found 1124 strong pixels on image 232
# Found 1067 strong pixels on image 233
# Found 1126 strong pixels on image 234
# Found 1292 strong pixels on image 235
# Found 1293 strong pixels on image 236
# Found 1338 strong pixels on image 237
# Found 1288 strong pixels on image 238
# Found 1235 strong pixels on image 239
# Found 1176 strong pixels on image 240
# Found 1193 strong pixels on image 241
# Found 1151 strong pixels on image 242
# Found 1208 strong pixels on image 243
# Found 1158 strong pixels on image 244
# Found 1264 strong pixels on image 245
# Found 1171 strong pixels on image 246
# Found 1284 strong pixels on image 247
# Found 1233 strong pixels on image 248
# Found 1358 strong pixels on image 249
# Found 1301 strong pixels on image 250
# Found 1375 strong pixels on image 251
# Found 1368 strong pixels on image 252
# Found 1191 strong pixels on image 253
# Found 1315 strong pixels on image 254
# Found 1240 strong pixels on image 255
# Found 1290 strong pixels on image 256
# Found 1199 strong pixels on image 257
# Found 1320 strong pixels on image 258
# Found 1224 strong pixels on image 259
# Found 1205 strong pixels on image 260
# Found 1116 strong pixels on image 261
# Found 1183 strong pixels on image 262
# Found 1334 strong pixels on image 263
# Found 1409 strong pixels on image 264
# Found 1329 strong pixels on image 265
# Found 1351 strong pixels on image 266
# Found 1333 strong pixels on image 267
# Found 1316 strong pixels on image 268
# Found 1411 strong pixels on image 269
# Found 1344 strong pixels on image 270
# Found 1217 strong pixels on image 271
# Found 1443 strong pixels on image 272
# Found 1399 strong pixels on image 273
# Found 1361 strong pixels on image 274
# Found 1402 strong pixels on image 275
# Found 1200 strong pixels on image 276
# Found 1179 strong pixels on image 277
# Found 1192 strong pixels on image 278
# Found 1230 strong pixels on image 279
# Found 1217 strong pixels on image 280
# Found 1369 strong pixels on image 281
# Found 1289 strong pixels on image 282
# Found 1225 strong pixels on image 283
# Found 1165 strong pixels on image 284
# Found 1194 strong pixels on image 285
# Found 1196 strong pixels on image 286
# Found 1077 strong pixels on image 287
# Found 1117 strong pixels on image 288
# Found 1212 strong pixels on image 289
# Found 1229 strong pixels on image 290
# Found 1377 strong pixels on image 291
# Found 1361 strong pixels on image 292
# Found 1227 strong pixels on image 293
# Found 1242 strong pixels on image 294
# Found 1303 strong pixels on image 295
# Found 1144 strong pixels on image 296
# Found 1085 strong pixels on image 297
# Found 1249 strong pixels on image 298
# Found 1235 strong pixels on image 299
# Found 1258 strong pixels on image 300
# Found 1177 strong pixels on image 301
# Found 1188 strong pixels on image 302
# Found 1290 strong pixels on image 303
# Found 1243 strong pixels on image 304
# Found 1226 strong pixels on image 305
# Found 1069 strong pixels on image 306
# Found 1123 strong pixels on image 307
# Found 1115 strong pixels on image 308
# Found 1092 strong pixels on image 309
# Found 1253 strong pixels on image 310
# Found 1123 strong pixels on image 311
# Found 1168 strong pixels on image 312
# Found 1142 strong pixels on image 313
# Found 1084 strong pixels on image 314
# Found 1188 strong pixels on image 315
# Found 1155 strong pixels on image 316
# Found 1070 strong pixels on image 317
# Found 1322 strong pixels on image 318
# Found 1205 strong pixels on image 319
# Found 1298 strong pixels on image 320
# Found 1321 strong pixels on image 321
# Found 1179 strong pixels on image 322
# Found 1158 strong pixels on image 323
# Found 1078 strong pixels on image 324
# Found 1203 strong pixels on image 325
# Found 1183 strong pixels on image 326
# Found 1114 strong pixels on image 327
# Found 1007 strong pixels on image 328
# Found 1135 strong pixels on image 329
# Found 1325 strong pixels on image 330
# Found 974 strong pixels on image 331
# Found 1142 strong pixels on image 332
# Found 1199 strong pixels on image 333
# Found 1111 strong pixels on image 334
# Found 1175 strong pixels on image 335
# Found 1200 strong pixels on image 336
# Found 1579 strong pixels on image 337
# Found 1140 strong pixels on image 338
# Found 1011 strong pixels on image 339
# Found 1011 strong pixels on image 340
# Found 1106 strong pixels on image 341
# Found 1128 strong pixels on image 342
# Found 1026 strong pixels on image 343
# Found 940 strong pixels on image 344
# Found 1173 strong pixels on image 345
# Found 1062 strong pixels on image 346
# Found 1184 strong pixels on image 347
# Found 1093 strong pixels on image 348
# Found 1215 strong pixels on image 349
# Found 1150 strong pixels on image 350
# Found 1180 strong pixels on image 351
# Found 1256 strong pixels on image 352
# Found 1139 strong pixels on image 353
# Found 1125 strong pixels on image 354
# Found 1082 strong pixels on image 355
# Found 1350 strong pixels on image 356
# Found 1086 strong pixels on image 357
# Found 1014 strong pixels on image 358
# Found 1173 strong pixels on image 359
# Found 1197 strong pixels on image 360
# Found 1373 strong pixels on image 361
# Found 1159 strong pixels on image 362
# Found 1158 strong pixels on image 363
# Found 1364 strong pixels on image 364
# Found 1311 strong pixels on image 365
# Found 1330 strong pixels on image 366
# Found 1312 strong pixels on image 367
# Found 1246 strong pixels on image 368
# Found 1247 strong pixels on image 369
# Found 1223 strong pixels on image 370
# Found 1202 strong pixels on image 371
# Found 1186 strong pixels on image 372
# Found 1326 strong pixels on image 373
# Found 1359 strong pixels on image 374
# Found 1116 strong pixels on image 375
# Found 1284 strong pixels on image 376
# Found 1305 strong pixels on image 377
# Found 1348 strong pixels on image 378
# Found 1235 strong pixels on image 379
# Found 1216 strong pixels on image 380
# Found 1164 strong pixels on image 381
# Found 1165 strong pixels on image 382
# Found 1156 strong pixels on image 383
# Found 1066 strong pixels on image 384
# Found 1096 strong pixels on image 385
# Found 1116 strong pixels on image 386
# Found 952 strong pixels on image 387
# Found 1021 strong pixels on image 388
# Found 1082 strong pixels on image 389
# Found 1139 strong pixels on image 390
# Found 1213 strong pixels on image 391
# Found 1217 strong pixels on image 392
# Found 1431 strong pixels on image 393
# Found 1264 strong pixels on image 394
# Found 1140 strong pixels on image 395
# Found 1300 strong pixels on image 396
# Found 1171 strong pixels on image 397
# Found 1206 strong pixels on image 398
# Found 1155 strong pixels on image 399
# Found 1301 strong pixels on image 400
# Found 1127 strong pixels on image 401
# Found 1057 strong pixels on image 402
# Found 1098 strong pixels on image 403
# Found 1178 strong pixels on image 404
# Found 1207 strong pixels on image 405
# Found 1224 strong pixels on image 406
# Found 1105 strong pixels on image 407
# Found 1175 strong pixels on image 408
# Found 1191 strong pixels on image 409
# Found 1185 strong pixels on image 410
# Found 1157 strong pixels on image 411
# Found 1108 strong pixels on image 412
# Found 1235 strong pixels on image 413
# Found 1397 strong pixels on image 414
# Found 1243 strong pixels on image 415
# Found 1233 strong pixels on image 416
# Found 1221 strong pixels on image 417
# Found 1206 strong pixels on image 418
# Found 1259 strong pixels on image 419
# Found 942 strong pixels on image 420
# Found 1040 strong pixels on image 421
# Found 1079 strong pixels on image 422
# Found 1073 strong pixels on image 423
# Found 1218 strong pixels on image 424
# Found 1228 strong pixels on image 425
# Found 1160 strong pixels on image 426
# Found 1050 strong pixels on image 427
# Found 1118 strong pixels on image 428
# Found 1201 strong pixels on image 429
# Found 1332 strong pixels on image 430
# Found 1358 strong pixels on image 431
# Found 1236 strong pixels on image 432
# Found 1317 strong pixels on image 433
# Found 1263 strong pixels on image 434
# Found 1321 strong pixels on image 435
# Found 1335 strong pixels on image 436
# Found 1274 strong pixels on image 437
# Found 1408 strong pixels on image 438
# Found 1244 strong pixels on image 439
# Found 1326 strong pixels on image 440
# Found 1187 strong pixels on image 441
# Found 1246 strong pixels on image 442
# Found 1146 strong pixels on image 443
# Found 1070 strong pixels on image 444
# Found 1105 strong pixels on image 445
# Found 1094 strong pixels on image 446
# Found 1221 strong pixels on image 447
# Found 1165 strong pixels on image 448
# Found 1186 strong pixels on image 449
# Found 1205 strong pixels on image 450
# Found 1516 strong pixels on image 451
# Found 1348 strong pixels on image 452
# Found 1222 strong pixels on image 453
# Found 1067 strong pixels on image 454
# Found 1016 strong pixels on image 455
# Found 1188 strong pixels on image 456
# Found 1369 strong pixels on image 457
# Found 1247 strong pixels on image 458
# Found 1324 strong pixels on image 459
# Found 1295 strong pixels on image 460
# Found 1342 strong pixels on image 461
# Found 1179 strong pixels on image 462
# Found 1155 strong pixels on image 463
# Found 1213 strong pixels on image 464
# Found 1062 strong pixels on image 465
# Found 1073 strong pixels on image 466
# Found 1224 strong pixels on image 467
# Found 1230 strong pixels on image 468
# Found 1274 strong pixels on image 469
# Found 1304 strong pixels on image 470
# Found 1299 strong pixels on image 471
# Found 1183 strong pixels on image 472
# Found 1258 strong pixels on image 473
# Found 1235 strong pixels on image 474
# Found 1269 strong pixels on image 475
# Found 1259 strong pixels on image 476
# Found 1276 strong pixels on image 477
# Found 1226 strong pixels on image 478
# Found 1299 strong pixels on image 479
# Found 1234 strong pixels on image 480
# Found 1279 strong pixels on image 481
# Found 1160 strong pixels on image 482
# Found 1154 strong pixels on image 483
# Found 1102 strong pixels on image 484
# Found 1300 strong pixels on image 485
# Found 1295 strong pixels on image 486
# Found 1173 strong pixels on image 487
# Found 1245 strong pixels on image 488
# Found 1287 strong pixels on image 489
# Found 1296 strong pixels on image 490
# Found 1256 strong pixels on image 491
# Found 1347 strong pixels on image 492
# Found 1401 strong pixels on image 493
# Found 1242 strong pixels on image 494
# Found 1141 strong pixels on image 495
# Found 1181 strong pixels on image 496
# Found 1208 strong pixels on image 497
# Found 1187 strong pixels on image 498
# Found 1182 strong pixels on image 499
# Found 1588 strong pixels on image 500
#
# Extracted 62868 spots
# Removed 9890 spots with size < 3 pixels
# Removed 1 spots with size > 1000 pixels
# Calculated 52977 spot centroids
# Calculated 52977 spot intensities
# Filtered 52960 of 52977 spots by peak-centroid distance
#
# Histogram of per-image spot count for imageset 0:
# 52960 spots found on 500 images (max 1172 / bin)
# *
# ********* ** *
# ***************** *** ** *      *                          *
# ****************************************** ******* ** ******
# ************************************************************
# ************************************************************
# ************************************************************
# ************************************************************
# ************************************************************
# ************************************************************
# 1                         image                          500
#
# --------------------------------------------------------------------------------
# Saved 52960 reflections to strong.refl

# %% [markdown]
# ### Indexing
#
# The indexing step assigns Miller indices to each diffraction spot. When processing an unknown crystal, it is usually necessary to re-index the data after space group determination. Here, the space group is known (the insulin crystal is I 2<sub>1</sub>3, space group number 199), and we can avoid having to re-index later by passing this information to `dials.index`.

# %%
# !dials.index imported.expt strong.refl space_group=199
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.24
# The following parameters have been modified:
#
# indexing {
#   known_symmetry {
#     space_group = "I 21 3"
#   }
# }
# input {
#   experiments = imported.expt
#   reflections = strong.refl
# }
#
# Found max_cell: 74.3 Angstrom
# Setting d_min: 1.45
# FFT gridding: (256,256,256)
# Number of centroids used: 52090
# Candidate solutions:
# +-------------------------------------+----------+----------------+------------+-------------+-------------------+-----------+-----------------+-----------------+
# | unit_cell                           |   volume |   volume score |   #indexed |   % indexed |   % indexed score |   rmsd_xy |   rmsd_xy score |   overall score |
# |-------------------------------------+----------+----------------+------------+-------------+-------------------+-----------+-----------------+-----------------|
# | 68.57 68.57 68.57 109.5 109.5 109.5 |   248153 |           0.02 |      49759 |          95 |              0.06 |      0.07 |            0.04 |            0.12 |
# | 68.49 68.49 68.49 109.5 109.5 109.5 |   247299 |           0.02 |      51980 |          99 |              0    |      0.08 |            0.13 |            0.14 |
# | 68.52 68.52 68.52 109.5 109.5 109.5 |   247697 |           0.02 |      51950 |          99 |              0    |      0.08 |            0.13 |            0.14 |
# | 68.63 68.63 68.63 109.5 109.5 109.5 |   248842 |           0.02 |      50967 |          97 |              0.03 |      0.08 |            0.11 |            0.16 |
# | 68.59 68.59 68.59 109.5 109.5 109.5 |   248444 |           0.02 |      50400 |          96 |              0.04 |      0.08 |            0.11 |            0.17 |
# | 68.58 68.58 68.58 109.5 109.5 109.5 |   248283 |           0.02 |      51969 |          99 |              0    |      0.08 |            0.16 |            0.18 |
# | 68.51 68.51 68.51 109.5 109.5 109.5 |   247540 |           0.02 |      51949 |          99 |              0    |      0.08 |            0.17 |            0.19 |
# | 68.49 68.49 68.49 109.5 109.5 109.5 |   247280 |           0.02 |      51974 |          99 |              0    |      0.08 |            0.18 |            0.2  |
# | 68.58 68.58 68.58 109.5 109.5 109.5 |   248330 |           0.02 |      50960 |          97 |              0.03 |      0.08 |            0.15 |            0.2  |
# | 68.66 68.66 68.66 109.5 109.5 109.5 |   249127 |           0.03 |      50694 |          97 |              0.04 |      0.08 |            0.17 |            0.23 |
# | 68.41 68.41 68.41 109.5 109.5 109.5 |   246470 |           0.01 |      50209 |          96 |              0.05 |      0.08 |            0.17 |            0.23 |
# | 68.65 68.65 68.65 109.5 109.5 109.5 |   249020 |           0.03 |      47783 |          91 |              0.12 |      0.08 |            0.1  |            0.25 |
# | 68.68 68.68 68.68 109.5 109.5 109.5 |   249332 |           0.03 |      50487 |          96 |              0.04 |      0.08 |            0.19 |            0.26 |
# | 68.36 68.36 68.36 109.5 109.5 109.5 |   245865 |           0.01 |      48483 |          93 |              0.1  |      0.08 |            0.16 |            0.26 |
# | 68.62 68.62 68.62 109.5 109.5 109.5 |   248738 |           0.02 |      50458 |          96 |              0.04 |      0.08 |            0.24 |            0.31 |
# | 68.38 68.38 68.38 109.5 109.5 109.5 |   246157 |           0.01 |      44087 |          84 |              0.24 |      0.08 |            0.08 |            0.33 |
# | 68.25 68.25 68.25 109.5 109.5 109.5 |   244684 |           0    |      46590 |          89 |              0.16 |      0.08 |            0.18 |            0.33 |
# | 68.37 68.37 68.37 109.5 109.5 109.5 |   246068 |           0.01 |      44036 |          84 |              0.24 |      0.08 |            0.11 |            0.35 |
# | 68.27 68.27 68.27 109.5 109.5 109.5 |   244958 |           0    |      44621 |          85 |              0.22 |      0.08 |            0.13 |            0.36 |
# | 68.45 68.45 68.45 109.5 109.5 109.5 |   246897 |           0.01 |      44966 |          86 |              0.21 |      0.08 |            0.15 |            0.37 |
# | 68.33 68.33 68.33 109.5 109.5 109.5 |   245592 |           0.01 |      42618 |          81 |              0.29 |      0.08 |            0.1  |            0.39 |
# | 68.49 68.49 68.49 109.5 109.5 109.5 |   247314 |           0.02 |      45103 |          86 |              0.2  |      0.08 |            0.18 |            0.4  |
# | 68.42 68.42 68.42 109.5 109.5 109.5 |   246563 |           0.01 |      43039 |          82 |              0.27 |      0.08 |            0.12 |            0.4  |
# | 68.53 68.53 68.53 109.5 109.5 109.5 |   247733 |           0.02 |      46198 |          88 |              0.17 |      0.08 |            0.22 |            0.41 |
# | 68.37 68.37 68.37 109.5 109.5 109.5 |   246036 |           0.01 |      42537 |          81 |              0.29 |      0.08 |            0.11 |            0.41 |
# | 68.42 68.42 68.42 109.5 109.5 109.5 |   246606 |           0.01 |      44953 |          86 |              0.21 |      0.08 |            0.19 |            0.41 |
# | 68.35 68.35 68.35 109.5 109.5 109.5 |   245785 |           0.01 |      42070 |          80 |              0.31 |      0.08 |            0.1  |            0.41 |
# | 68.33 68.33 68.33 109.5 109.5 109.5 |   245575 |           0.01 |      42441 |          81 |              0.29 |      0.08 |            0.12 |            0.42 |
# | 68.39 68.39 68.39 109.5 109.5 109.5 |   246248 |           0.01 |      39105 |          75 |              0.41 |      0.07 |            0    |            0.42 |
# | 68.41 68.41 68.41 109.5 109.5 109.5 |   246416 |           0.01 |      44032 |          84 |              0.24 |      0.08 |            0.17 |            0.42 |
# | 68.38 68.38 68.38 109.5 109.5 109.5 |   246081 |           0.01 |      41679 |          80 |              0.32 |      0.08 |            0.1  |            0.43 |
# | 68.43 68.43 68.43 109.5 109.5 109.5 |   246705 |           0.01 |      44399 |          85 |              0.23 |      0.08 |            0.19 |            0.43 |
# | 68.42 68.42 68.42 109.5 109.5 109.5 |   246542 |           0.01 |      43201 |          82 |              0.27 |      0.08 |            0.16 |            0.44 |
# | 68.51 68.51 68.51 109.5 109.5 109.5 |   247574 |           0.02 |      43893 |          84 |              0.24 |      0.08 |            0.18 |            0.44 |
# | 68.48 68.48 68.48 109.5 109.5 109.5 |   247177 |           0.01 |      45989 |          88 |              0.18 |      0.09 |            0.27 |            0.46 |
# | 68.42 68.42 68.42 109.5 109.5 109.5 |   246568 |           0.01 |      39992 |          76 |              0.38 |      0.08 |            0.08 |            0.47 |
# | 68.41 68.41 68.41 109.5 109.5 109.5 |   246450 |           0.01 |      42123 |          80 |              0.3  |      0.08 |            0.17 |            0.48 |
# | 68.46 68.46 68.46 109.5 109.5 109.5 |   247030 |           0.01 |      36756 |          70 |              0.5  |      0.07 |            0.04 |            0.56 |
# | 68.33 68.33 68.33 109.5 109.5 109.5 |   245567 |           0.01 |      40291 |          77 |              0.37 |      0.08 |            0.19 |            0.56 |
# | 68.46 68.46 68.46 109.5 109.5 109.5 |   247032 |           0.01 |      37702 |          72 |              0.46 |      0.08 |            0.13 |            0.61 |
# | 68.71 68.71 68.71 109.5 109.5 109.5 |   249719 |           0.03 |      39234 |          75 |              0.41 |      0.08 |            0.18 |            0.62 |
# | 68.27 68.27 68.27 109.5 109.5 109.5 |   244969 |           0    |      36786 |          70 |              0.5  |      0.08 |            0.21 |            0.71 |
# | 68.35 68.35 68.35 109.5 109.5 109.5 |   245796 |           0.01 |      41606 |          79 |              0.32 |      0.1  |            0.5  |            0.83 |
# | 68.31 68.31 68.31 109.5 109.5 109.5 |   245427 |           0    |      25412 |          48 |              1.03 |      0.08 |            0.08 |            1.12 |
# | 68.45 68.45 68.45 109.5 109.5 109.5 |   246918 |           0.01 |      25323 |          48 |              1.04 |      0.08 |            0.08 |            1.13 |
# | 68.62 68.62 68.62 109.5 109.5 109.5 |   248686 |           0.02 |      26198 |          50 |              0.99 |      0.08 |            0.15 |            1.16 |
# | 68.54 68.54 68.54 109.5 109.5 109.5 |   247882 |           0.02 |      28253 |          54 |              0.88 |      0.09 |            0.26 |            1.16 |
# | 68.37 68.37 68.37 109.5 109.5 109.5 |   246031 |           0.01 |      28103 |          54 |              0.89 |      0.09 |            0.31 |            1.21 |
# | 68.54 68.54 68.54 109.5 109.5 109.5 |   247914 |           0.02 |      24968 |          48 |              1.06 |      0.08 |            0.15 |            1.23 |
# | 68.75 68.75 68.75 109.5 109.5 109.5 |   250108 |           0.03 |      26107 |          50 |              0.99 |      0.09 |            0.28 |            1.3  |
# +-------------------------------------+----------+----------------+------------+-------------+-------------------+-----------+-----------------+-----------------+
# Using d_min_step 0.0
#
# Indexed crystal models:
# model 1 (51790 reflections):
# Crystal:
#     Unit cell: 79.174, 79.174, 79.174, 90.000, 90.000, 90.000
#     Space group: I 21 3
#     U matrix:  {{-0.8074, -0.1105,  0.5796},
#                 {-0.5900,  0.1525, -0.7929},
#                 {-0.0008, -0.9821, -0.1883}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 {-0.0000, -0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0075,  0.0019, -0.0100},
#                 {-0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       51790 |           623 |           561 |        98.8 |
# +------------+-------------+---------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 1)
# ################################################################################
#
#
# Summary statistics for 51722 observations matched to predictions:
# +-------------------+--------+---------+---------+----------+--------+
# |                   |    Min |      Q1 |     Med |       Q3 |    Max |
# |-------------------+--------+---------+---------+----------+--------|
# | Xc - Xo (mm)      | -1.047 | -0.2699 | -0.1859 | -0.07432 | 0.5794 |
# | Yc - Yo (mm)      | -5.251 | -0.5115 |  -0.364 |  -0.2542 |  6.448 |
# | Phic - Phio (deg) | -6.388 |  0.1134 |   0.187 |   0.2603 |  4.409 |
# | X weights         |  251.7 |   387.3 |   401.3 |    404.9 |  405.6 |
# | Y weights         |  239.2 |   374.1 |   396.1 |    403.9 |  405.6 |
# | Phi weights       |  964.3 |    1199 |    1200 |     1200 |   1200 |
# +-------------------+--------+---------+---------+----------+--------+
#
# Detecting centroid outliers using the Tukey algorithm
# 6809 reflections have been flagged as outliers
# 44913 reflections remain in the manager
#
# Summary statistics for 44913 observations matched to predictions:
# +-------------------+---------+---------+---------+----------+--------+
# |                   |     Min |      Q1 |     Med |       Q3 |    Max |
# |-------------------+---------+---------+---------+----------+--------|
# | Xc - Xo (mm)      | -0.6269 | -0.2647 | -0.1829 | -0.07685 | 0.3509 |
# | Yc - Yo (mm)      |  -1.075 | -0.4926 | -0.3586 |   -0.259 | 0.2538 |
# | Phic - Phio (deg) | -0.1591 |  0.1244 |  0.1911 |   0.2569 | 0.5417 |
# | X weights         |     272 |   391.7 |   402.2 |      405 |  405.6 |
# | Y weights         |   243.1 |   376.8 |     397 |      404 |  405.6 |
# | Phi weights       |   994.7 |    1199 |    1200 |     1200 |   1200 |
# +-------------------+---------+---------+---------+----------+--------+
#
# There are 11 parameters to refine against 5000 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   5000 | 0.23432  | 0.42883  |   0.22333  |
# |      1 |   5000 | 0.14457  | 0.16371  |   0.1612   |
# |      2 |   5000 | 0.12186  | 0.13492  |   0.083399 |
# |      3 |   5000 | 0.08563  | 0.092916 |   0.04178  |
# |      4 |   5000 | 0.051861 | 0.055496 |   0.029142 |
# |      5 |   5000 | 0.042344 | 0.046686 |   0.02307  |
# |      6 |   5000 | 0.04152  | 0.046345 |   0.022196 |
# |      7 |   5000 | 0.041474 | 0.046348 |   0.022184 |
# |      8 |   5000 | 0.041472 | 0.046348 |   0.022185 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   5000 |  0.24112 |  0.26946 |    0.22185 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (51790 reflections):
# Crystal:
#     Unit cell: 79.5058(13), 79.5058(13), 79.5058(13), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       51790 |           623 |           561 |        98.8 |
# +------------+-------------+---------------+---------------+-------------+
# Increasing resolution to 1.41 Angstrom
#
# Indexed crystal models:
# model 1 (52390 reflections):
# Crystal:
#     Unit cell: 79.5058(13), 79.5058(13), 79.5058(13), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 {-0.0000,  0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       52480 |           334 |           299 |        99.4 |
# +------------+-------------+---------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 2)
# ################################################################################
#
#
# Summary statistics for 52325 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+--------+
# |                   |     Min |       Q1 |        Med |      Q3 |    Max |
# |-------------------+---------+----------+------------+---------+--------|
# | Xc - Xo (mm)      | -0.4597 | -0.02168 |   0.002142 |  0.0236 |  0.541 |
# | Yc - Yo (mm)      | -0.4438 | -0.02825 | -9.403e-05 | 0.02488 |  0.493 |
# | Phic - Phio (deg) | -0.9792 | -0.01762 |  -0.001293 | 0.01584 | 0.3447 |
# | X weights         |   251.7 |    386.7 |      401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    373.1 |      395.9 |   403.9 |  405.6 |
# | Phi weights       |   964.3 |     1199 |       1200 |    1200 |   1200 |
# +-------------------+---------+----------+------------+---------+--------+
#
# Detecting centroid outliers using the Tukey algorithm
# 3268 reflections have been flagged as outliers
# 49057 reflections remain in the manager
#
# Summary statistics for 49057 observations matched to predictions:
# +-------------------+----------+----------+------------+---------+---------+
# |                   |      Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+----------+----------+------------+---------+---------|
# | Xc - Xo (mm)      |  -0.1147 | -0.01994 |   0.002524 | 0.02318 |  0.1156 |
# | Yc - Yo (mm)      |  -0.1593 | -0.02695 | -1.385e-06 | 0.02373 |  0.1644 |
# | Phic - Phio (deg) | -0.07075 | -0.01739 |  -0.001256 | 0.01556 | 0.07081 |
# | X weights         |    251.7 |    388.5 |      401.6 |     405 |   405.6 |
# | Y weights         |    239.2 |    374.8 |      396.5 |   403.9 |   405.6 |
# | Phi weights       |    964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+----------+----------+------------+---------+---------+
#
# There are 11 parameters to refine against 5000 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   5000 | 0.034982 | 0.038406 |   0.021993 |
# |      1 |   5000 | 0.035935 | 0.037983 |   0.020754 |
# |      2 |   5000 | 0.035903 | 0.038455 |   0.020226 |
# |      3 |   5000 | 0.035857 | 0.038661 |   0.020084 |
# |      4 |   5000 | 0.035828 | 0.038696 |   0.020066 |
# |      5 |   5000 | 0.03582  | 0.0387   |   0.020065 |
# |      6 |   5000 | 0.035819 | 0.038701 |   0.020065 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   5000 |  0.20825 |  0.22501 |    0.20065 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (52390 reflections):
# Crystal:
#     Unit cell: 79.5203(8), 79.5203(8), 79.5203(8), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 { 0.0000,  0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       52390 |           424 |           381 |        99.2 |
# +------------+-------------+---------------+---------------+-------------+
# Increasing resolution to 1.37 Angstrom
#
# Indexed crystal models:
# model 1 (52487 reflections):
# Crystal:
#     Unit cell: 79.5203(8), 79.5203(8), 79.5203(8), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 { 0.0000,  0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       52488 |           424 |           382 |        99.2 |
# +------------+-------------+---------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 3)
# ################################################################################
#
#
# Summary statistics for 52422 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+--------+
# |                   |     Min |       Q1 |        Med |      Q3 |    Max |
# |-------------------+---------+----------+------------+---------+--------|
# | Xc - Xo (mm)      | -0.4577 | -0.02225 |   0.001893 | 0.02383 | 0.5431 |
# | Yc - Yo (mm)      | -0.4438 | -0.02661 |   0.001629 | 0.02677 | 0.4923 |
# | Phic - Phio (deg) | -0.9587 | -0.01588 | -0.0003145 | 0.01606 | 0.3366 |
# | X weights         |   251.7 |    386.6 |      401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |      373 |      395.8 |   403.8 |  405.6 |
# | Phi weights       |   964.3 |     1199 |       1200 |    1200 |   1200 |
# +-------------------+---------+----------+------------+---------+--------+
#
# Detecting centroid outliers using the Tukey algorithm
# 3024 reflections have been flagged as outliers
# 49398 reflections remain in the manager
#
# Summary statistics for 49398 observations matched to predictions:
# +-------------------+----------+----------+------------+---------+---------+
# |                   |      Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+----------+----------+------------+---------+---------|
# | Xc - Xo (mm)      |  -0.1192 | -0.02047 |   0.002344 | 0.02351 |  0.1209 |
# | Yc - Yo (mm)      |  -0.1604 | -0.02557 |   0.001631 |  0.0257 |  0.1695 |
# | Phic - Phio (deg) | -0.06669 | -0.01576 | -0.0002904 | 0.01592 | 0.06533 |
# | X weights         |    251.7 |    388.3 |      401.6 |     405 |   405.6 |
# | Y weights         |    239.2 |    374.6 |      396.5 |   403.9 |   405.6 |
# | Phi weights       |    964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+----------+----------+------------+---------+---------+
#
# There are 11 parameters to refine against 5000 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   5000 | 0.035322 | 0.038944 |   0.019944 |
# |      1 |   5000 | 0.035587 | 0.038786 |   0.01986  |
# |      2 |   5000 | 0.035584 | 0.038841 |   0.019817 |
# |      3 |   5000 | 0.035603 | 0.038838 |   0.019801 |
# |      4 |   5000 | 0.035624 | 0.038819 |   0.019796 |
# |      5 |   5000 | 0.03563  | 0.038814 |   0.019794 |
# |      6 |   5000 | 0.035629 | 0.038815 |   0.019793 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   5000 |  0.20715 |  0.22567 |    0.19793 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (52487 reflections):
# Crystal:
#     Unit cell: 79.5227(7), 79.5227(7), 79.5227(7), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 { 0.0000,  0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       52487 |           425 |           383 |        99.2 |
# +------------+-------------+---------------+---------------+-------------+
# Increasing resolution to 1.32 Angstrom
#
# Indexed crystal models:
# model 1 (52519 reflections):
# Crystal:
#     Unit cell: 79.5227(7), 79.5227(7), 79.5227(7), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 { 0.0000,  0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       52522 |           422 |           380 |        99.2 |
# +------------+-------------+---------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 4)
# ################################################################################
#
#
# Summary statistics for 52454 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+--------+
# |                   |     Min |       Q1 |        Med |      Q3 |    Max |
# |-------------------+---------+----------+------------+---------+--------|
# | Xc - Xo (mm)      | -0.4576 | -0.02293 |   0.001498 | 0.02337 |  0.543 |
# | Yc - Yo (mm)      | -0.4439 | -0.02726 |   0.001032 |  0.0262 | 0.4915 |
# | Phic - Phio (deg) | -0.9563 | -0.01615 | -0.0007018 | 0.01557 | 0.3367 |
# | X weights         |   251.7 |    386.5 |      401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.9 |      395.8 |   403.8 |  405.6 |
# | Phi weights       |   964.3 |     1199 |       1200 |    1200 |   1200 |
# +-------------------+---------+----------+------------+---------+--------+
#
# Detecting centroid outliers using the Tukey algorithm
# 2994 reflections have been flagged as outliers
# 49460 reflections remain in the manager
#
# Summary statistics for 49460 observations matched to predictions:
# +-------------------+----------+----------+------------+---------+---------+
# |                   |      Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+----------+----------+------------+---------+---------|
# | Xc - Xo (mm)      |  -0.1213 | -0.02109 |   0.001975 | 0.02308 |  0.1205 |
# | Yc - Yo (mm)      |  -0.1609 |  -0.0262 |   0.001054 | 0.02516 |  0.1689 |
# | Phic - Phio (deg) | -0.06654 | -0.01604 | -0.0006661 | 0.01543 | 0.06334 |
# | X weights         |    251.7 |    388.2 |      401.5 |     405 |   405.6 |
# | Y weights         |    239.2 |    374.6 |      396.5 |   403.9 |   405.6 |
# | Phi weights       |    964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+----------+----------+------------+---------+---------+
#
# There are 11 parameters to refine against 5000 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   5000 | 0.035912 | 0.038517 |   0.019757 |
# |      1 |   5000 | 0.035912 | 0.038548 |   0.019725 |
# |      2 |   5000 | 0.035911 | 0.038573 |   0.019707 |
# |      3 |   5000 | 0.035915 | 0.038575 |   0.019702 |
# |      4 |   5000 | 0.03592  | 0.038571 |   0.019702 |
# |      5 |   5000 | 0.035922 | 0.038569 |   0.019702 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   5000 |  0.20885 |  0.22424 |    0.19702 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (52519 reflections):
# Crystal:
#     Unit cell: 79.5233(7), 79.5233(7), 79.5233(7), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 { 0.0000,  0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       52519 |           425 |           383 |        99.2 |
# +------------+-------------+---------------+---------------+-------------+
# Increasing resolution to 1.28 Angstrom
#
# Indexed crystal models:
# model 1 (52535 reflections):
# Crystal:
#     Unit cell: 79.5233(7), 79.5233(7), 79.5233(7), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 { 0.0000,  0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       52536 |           424 |           383 |        99.2 |
# +------------+-------------+---------------+---------------+-------------+
#
# ################################################################################
# Starting refinement (macro-cycle 5)
# ################################################################################
#
#
# Summary statistics for 52470 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+--------+
# |                   |     Min |       Q1 |        Med |      Q3 |    Max |
# |-------------------+---------+----------+------------+---------+--------|
# | Xc - Xo (mm)      | -0.4564 | -0.02221 |    0.00224 | 0.02406 | 0.5439 |
# | Yc - Yo (mm)      | -0.4438 | -0.02769 |  0.0007341 | 0.02596 | 0.4916 |
# | Phic - Phio (deg) | -0.9551 | -0.01621 | -0.0007232 | 0.01542 | 0.3356 |
# | X weights         |   251.7 |    386.5 |      401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.9 |      395.8 |   403.8 |  405.6 |
# | Phi weights       |   964.3 |     1199 |       1200 |    1200 |   1200 |
# +-------------------+---------+----------+------------+---------+--------+
#
# Detecting centroid outliers using the Tukey algorithm
# 3006 reflections have been flagged as outliers
# 49464 reflections remain in the manager
#
# Summary statistics for 49464 observations matched to predictions:
# +-------------------+----------+----------+------------+---------+---------+
# |                   |      Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+----------+----------+------------+---------+---------|
# | Xc - Xo (mm)      |   -0.121 | -0.02032 |   0.002784 | 0.02384 |  0.1225 |
# | Yc - Yo (mm)      |  -0.1619 | -0.02665 |  0.0007522 | 0.02497 |  0.1692 |
# | Phic - Phio (deg) | -0.06554 | -0.01607 | -0.0006738 | 0.01527 | 0.06318 |
# | X weights         |    251.7 |    388.2 |      401.5 |     405 |   405.6 |
# | Y weights         |    239.2 |    374.6 |      396.5 |   403.9 |   405.6 |
# | Phi weights       |    964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+----------+----------+------------+---------+---------+
#
# There are 11 parameters to refine against 5000 reflections in 3 dimensions
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |   5000 | 0.036217 | 0.039061 |   0.019899 |
# |      1 |   5000 | 0.036038 | 0.039205 |   0.019899 |
# |      2 |   5000 | 0.036021 | 0.039224 |   0.019887 |
# |      3 |   5000 | 0.036008 | 0.03923  |   0.019883 |
# |      4 |   5000 | 0.036    | 0.039232 |   0.019883 |
# |      5 |   5000 | 0.035998 | 0.039232 |   0.019883 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   5000 |  0.20929 |   0.2281 |    0.19883 |
# +-------+--------+----------+----------+------------+
#
# Refined crystal models:
# model 1 (52535 reflections):
# Crystal:
#     Unit cell: 79.5235(7), 79.5235(7), 79.5235(7), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 { 0.0000, -0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       52535 |           425 |           383 |        99.2 |
# +------------+-------------+---------------+---------------+-------------+
# Saving refined experiments to indexed.expt
# Saving refined reflections to indexed.refl

# %% [markdown]
# For diffuse scattering, it's important to verify that all (or nearly all) peaks are indexed. There might be split Bragg reflections, multiple lattices, or salt crystals contaminating the signal. Or, the crystal might have slipped during data collection.
#
# Check that indexing was successful by examining the *dials.index* output.
#
# Find the table with "% indexed".
#
# ```
# +------------+-------------+---------------+---------------+-------------+
# |   Imageset |   # indexed |   # unindexed |   # unindexed |   % indexed |
# |            |             |         total |       non-ice |             |
# |------------+-------------+---------------+---------------+-------------|
# |          0 |       52535 |           425 |           383 |        99.2 |
# +------------+-------------+---------------+---------------+-------------+
# ```
#
# The fraction of indexed peaks should be close to 100%. A small percentage may suggest incorrect experimental geometry, multiple lattices, twinning, salt or ice diffraction, or other issues. The indexing results should be inspected by running `dials.image_viewer indexed.expt`. In our case, 99.2 percent of strong peaks were indexed (there were 425 unindexed peaks and 52535 indexed peaks).
#
# Find the table called "RMSDs by experiment".
#
# ```
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |   5000 |  0.20929 |   0.2281 |    0.19883 |
# +-------+--------+----------+----------+------------+
# ```
#
# This table includes the root mean square displacement (RMSD) between the predicted and observed spot centroids. If the RMSDs are less than ~1, this indicates that the indexing solution was successful and a single set of geometric parameters can describe the entire dataset accurately. However, if the crystal slips slightly during data collection or the lattice constants change, the spot predictions can be improved by fitting a scan-varying geometric model.

# %% [markdown]
# ### Geometry refinement
#
# Next we use `dials.refine` to fit a scan-varying model of the crystal geometry. This can be important if the lattice constants change due to radiation damage, or if the crystal is not held rigidly in the loop and slips during data collection.

# %%
# !dials.refine indexed.expt indexed.refl
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.24
# The following parameters have been modified:
#
# input {
#   experiments = indexed.expt
#   reflections = indexed.refl
# }
#
# Configuring refiner
# Setting outlier.nproc=96
#
# Summary statistics for 52470 observations matched to predictions:
# +-------------------+---------+----------+-----------+---------+--------+
# |                   |     Min |       Q1 |       Med |      Q3 |    Max |
# |-------------------+---------+----------+-----------+---------+--------|
# | Xc - Xo (mm)      | -0.4564 | -0.02197 |  0.002365 | 0.02414 | 0.5446 |
# | Yc - Yo (mm)      | -0.4446 | -0.02754 | 0.0007776 | 0.02611 | 0.4915 |
# | Phic - Phio (deg) |  -0.956 | -0.01689 | -0.001434 | 0.01472 | 0.3353 |
# | X weights         |   251.7 |    386.5 |     401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.9 |     395.8 |   403.8 |  405.6 |
# | Phi weights       |   964.3 |     1199 |      1200 |    1200 |   1200 |
# +-------------------+---------+----------+-----------+---------+--------+
#
# Detecting centroid outliers using the MCD algorithm
# 5907 reflections have been flagged as outliers
# 46563 reflections remain in the manager
#
# Summary statistics for 46563 observations matched to predictions:
# +-------------------+----------+----------+-----------+---------+---------+
# |                   |      Min |       Q1 |       Med |      Q3 |     Max |
# |-------------------+----------+----------+-----------+---------+---------|
# | Xc - Xo (mm)      |  -0.1048 | -0.01694 |  0.004127 | 0.02442 |  0.1266 |
# | Yc - Yo (mm)      |  -0.1701 | -0.02459 |  0.001352 | 0.02444 |  0.1736 |
# | Phic - Phio (deg) | -0.06686 | -0.01636 | -0.001254 | 0.01441 | 0.06227 |
# | X weights         |    251.7 |      390 |       402 |     405 |   405.6 |
# | Y weights         |    239.2 |    376.4 |     397.4 |   404.1 |   405.6 |
# | Phi weights       |    964.3 |     1199 |      1200 |    1200 |    1200 |
# +-------------------+----------+----------+-----------+---------+---------+
#
# There are 11 parameters to refine against 46563 reflections in 3 dimensions
# Performing refinement of a single Experiment...
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |  46563 | 0.032038 | 0.038339 |   0.019523 |
# |      1 |  46563 | 0.032934 | 0.037295 |   0.01948  |
# |      2 |  46563 | 0.032972 | 0.037189 |   0.019502 |
# |      3 |  46563 | 0.033006 | 0.037125 |   0.019509 |
# |      4 |  46563 | 0.033035 | 0.03709  |   0.01951  |
# |      5 |  46563 | 0.033047 | 0.037078 |   0.019511 |
# |      6 |  46563 | 0.033049 | 0.037076 |   0.019511 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |  46563 |  0.19214 |  0.21556 |    0.19511 |
# +-------+--------+----------+----------+------------+
# Updating predictions for indexed reflections
#
# Scan-varying refinement
# Configuring refiner
#
# Summary statistics for 52469 observations matched to predictions:
# +-------------------+---------+----------+------------+---------+--------+
# |                   |     Min |       Q1 |        Med |      Q3 |    Max |
# |-------------------+---------+----------+------------+---------+--------|
# | Xc - Xo (mm)      | -0.4596 | -0.02573 | -0.0002538 |  0.0221 | 0.5408 |
# | Yc - Yo (mm)      | -0.4373 | -0.02734 |  0.0004866 | 0.02527 | 0.4921 |
# | Phic - Phio (deg) | -0.9563 | -0.01603 | -0.0005176 | 0.01562 | 0.3351 |
# | X weights         |   251.7 |    386.5 |      401.2 |   404.9 |  405.6 |
# | Y weights         |   239.2 |    372.9 |      395.8 |   403.8 |  405.6 |
# | Phi weights       |   964.3 |     1199 |       1200 |    1200 |   1200 |
# +-------------------+---------+----------+------------+---------+--------+
#
# Detecting centroid outliers using the MCD algorithm
# 5665 reflections have been flagged as outliers
# 46804 reflections remain in the manager
#
# Summary statistics for 46804 observations matched to predictions:
# +-------------------+----------+----------+------------+---------+---------+
# |                   |      Min |       Q1 |        Med |      Q3 |     Max |
# |-------------------+----------+----------+------------+---------+---------|
# | Xc - Xo (mm)      |  -0.1126 |  -0.0207 |   0.001686 | 0.02242 |  0.1292 |
# | Yc - Yo (mm)      |  -0.1609 | -0.02437 |   0.001114 | 0.02387 |  0.1679 |
# | Phic - Phio (deg) | -0.06597 | -0.01548 | -0.0003843 |  0.0153 | 0.06809 |
# | X weights         |    251.7 |    389.8 |      401.9 |     405 |   405.6 |
# | Y weights         |    239.2 |    376.4 |      397.3 |   404.1 |   405.6 |
# | Phi weights       |    964.3 |     1199 |       1200 |    1200 |    1200 |
# +-------------------+----------+----------+------------+---------+---------+
#
# There are 15 parameters to refine against 46804 reflections in 3 dimensions
# Performing refinement of a single Experiment...
#
# Refinement steps:
# +--------+--------+----------+----------+------------+
# |   Step |   Nref |   RMSD_X |   RMSD_Y |   RMSD_Phi |
# |        |        |     (mm) |     (mm) |      (deg) |
# |--------+--------+----------+----------+------------|
# |      0 |  46804 | 0.0333   | 0.037161 |   0.019548 |
# |      1 |  46804 | 0.030829 | 0.031806 |   0.019785 |
# |      2 |  46804 | 0.030775 | 0.031862 |   0.019652 |
# |      3 |  46804 | 0.030737 | 0.031893 |   0.01955  |
# |      4 |  46804 | 0.030719 | 0.031906 |   0.019525 |
# |      5 |  46804 | 0.030711 | 0.031906 |   0.019522 |
# |      6 |  46804 | 0.030701 | 0.031899 |   0.019518 |
# |      7 |  46804 | 0.030685 | 0.031889 |   0.019515 |
# |      8 |  46804 | 0.030673 | 0.031882 |   0.019516 |
# |      9 |  46804 | 0.030669 | 0.03188  |   0.019519 |
# |     10 |  46804 | 0.030668 | 0.03188  |   0.019519 |
# +--------+--------+----------+----------+------------+
# RMSD no longer decreasing
#
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |  46804 |   0.1783 |  0.18535 |    0.19519 |
# +-------+--------+----------+----------+------------+
# Updating predictions for indexed reflections
#
# Final refined crystal model:
# Crystal:
#     Unit cell: 79.5230(2), 79.5230(2), 79.5230(2), 90.0, 90.0, 90.0
#     Space group: I 21 3
#     U matrix:  {{-0.8086, -0.1125,  0.5775},
#                 {-0.5884,  0.1495, -0.7946},
#                 { 0.0031, -0.9823, -0.1871}}
#     B matrix:  {{ 0.0126,  0.0000,  0.0000},
#                 { 0.0000,  0.0126,  0.0000},
#                 { 0.0000,  0.0000,  0.0126}}
#     A = UB:    {{-0.0102, -0.0014,  0.0073},
#                 {-0.0074,  0.0019, -0.0100},
#                 { 0.0000, -0.0124, -0.0024}}
#     A sampled at 501 scan points
# Saving refined experiments to refined.expt
# Saving reflections with updated predictions to refined.refl

# %% [markdown]
# To see if the spot predictions improved, find the table "RMSDs by experiment" in the text output:
#
# ```
# RMSDs by experiment:
# +-------+--------+----------+----------+------------+
# |   Exp |   Nref |   RMSD_X |   RMSD_Y |     RMSD_Z |
# |    id |        |     (px) |     (px) |   (images) |
# |-------+--------+----------+----------+------------|
# |     0 |  46804 |   0.1783 |  0.18535 |    0.19519 |
# +-------+--------+----------+----------+------------+
# ```
#
# Compared with the corresponding table from `dials.index`, the RMSDs have improved as we expected. However the improvement is modest. In our case, the indexing solution already had small RMSDs and refinement was not strictly necessary.

# %% [markdown]
# ### Diagnostic statistics and plots
#
# The `dials.report` function generates an html file with interactive plots. The report should be examined closely to catch any issues that would potentially complicate analysis of the diffuse scattering.

# %%
# !dials.report refined.expt refined.refl
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# The following parameters have been modified:
#
# input {
#   experiments = refined.expt
#   reflections = refined.refl
# }
#
# Analysing strong spots
#  Selected 52960 strong reflections.........................................0.01s
# Analysing reflection centroids
#  Selected 46804 refined reflections........................................0.01s
#  Analysing centroid differences with I/Sigma > 0
#  Analysing centroid differences in x/y with I/Sigma > 0
#  Analysing centroid differences in z with I/Sigma > 0
#  Analysing centroid differences vs phi with I/Sigma > 0
# Analysing reflection intensities
#  Selecting only integrated reflections...Analysing reference profiles
#  Skipping: following required fields not present:
#   intensity.prf.value
#   intensity.prf.variance
#   profile.correlation
# Analysing scan-varying crystal model
# Writing html report to: dials.report.html

# %% [markdown]
# Open the file `dials.report.html` in an internet browser (the file can also be opened by double-clicking in Jupyter Lab, however certain elements may not render correctly; if you are unable to expand the menus, click "Trust HTML" in the upper left corner of the window).
#
# Expand the tab called "Analysis of scan varying model". These plots should be checked to see whether the unit cell axes change significantly during data collection. Abrupt changes in the orientation parameters may indicate that the crystal slipped during data collection.
#
# Expand the tab called "Analysis of reflection centroids". Ideally, the error in X, Y positions should appear random across the detector face. In our dataset, the errors cluster in rectangular blocks corresponding to the detector modules. If sub-pixel accuracy is desired, the module alignments can be calibrated. Next, examine the plots of spot centroid errors. The spread of centroids around the mean should show a compact peak. If there are multiple peaks observed, then the crystal may be twinned or multiple lattice may be present (e.g. due to cracking).

# %% [markdown]
# ### Background image metadata
#
# An additional dataset was acquired for background subtraction in _mdx2_. We'll use `dials.import` and `dials.apply_mask` to create a metadata file `background.expt` that will be used in Part 4 of this tutorial.

# %%
# !dials.import images/insulin_2_bkg output.experiments=background.expt
# !dials.apply_mask background.expt input.mask=pixels.mask output.experiments=background.expt
# Out:
# DIALS (2018) Acta Cryst. D74, 85-97. https://doi.org/10.1107/S2059798317017235
# DIALS 3.24
# The following parameters have been modified:
#
# output {
#   experiments = "background.expt"
# }
# input {
#   experiments = <image files>
# }
#
# --------------------------------------------------------------------------------
#   format: <class 'dxtbx.format.FormatCBFMiniPilatusCHESS_6MSN127.FormatCBFMiniPilatusCHESS_6MSN127'>
#   template: /local/storage/steve/mdx2_dev/examples/insulin-tutorial/images/insulin_2_bkg/insulin_2_bkg_1_####.cbf.bz2:161:210
#   num images: 50
#   sequences:
#     still:    0
#     sweep:    1
#   num stills: 0
# --------------------------------------------------------------------------------
# Writing experiments to background.expt
# The following parameters have been modified:
#
# input {
#   mask = "pixels.mask"
#   experiments = background.expt
# }
# output {
#   experiments = "background.expt"
# }
#
# Writing experiments to background.expt
